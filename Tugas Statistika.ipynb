# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

#Membaca file dataset CSV dari Google Drive lalu menyimpannya ke variabel data
data = pd.read_csv('/content/drive/MyDrive/Tugas Statistika Random Sampling & T Distribusi/MovieData-2018-2020.csv')

#Menampilkan 5 baris pertama dari dataset
data.head()
# Out:
#                      name rating      genre  year  \
# 0           A Quiet Place  PG-13      Drama  2018
# 1  Avengers: Infinity War  PG-13     Action  2018
# 2              Deadpool 2      R     Action  2018
# 3       Bohemian Rhapsody  PG-13  Biography  2018
# 4           Black Panther  PG-13     Action  2018
#
#                             released  score     votes        director  \
# 0      April 6, 2018 (United States)    7.5  456000.0  John Krasinski
# 1     April 27, 2018 (United States)    8.4  897000.0   Anthony Russo
# 2       May 18, 2018 (United States)    7.7  505000.0    David Leitch
# 3   November 2, 2018 (United States)    7.9  476000.0    Bryan Singer
# 4  February 16, 2018 (United States)    7.3  661000.0    Ryan Coogler
#
#                writer               star         country       budget  \
# 0         Bryan Woods        Emily Blunt   United States   17000000.0
# 1  Christopher Markus  Robert Downey Jr.   United States  321000000.0
# ...

# %%
data["genre"].value_counts()
# Out:
# genre
# Action       88
# Comedy       45
# Drama        38
# Biography    29
# Animation    23
# Adventure    19
# Horror       15
# Crime        12
# Fantasy       3
# Thriller      1
# Sci-Fi        1
# Name: count, dtype: int64

# %%
#menghilangkan genre yang hanya berisi 1 judul
filtered_data = data.groupby('genre').filter(lambda x: len(x) > 1)
filtered_data["genre"].value_counts()
# Out:
# genre
# Action       88
# Comedy       45
# Drama        38
# Biography    29
# Animation    23
# Adventure    19
# Horror       15
# Crime        12
# Fantasy       3
# Name: count, dtype: int64

# %%
#stratifed sample genre
_, stratified_sample = train_test_split(
    filtered_data,
    test_size=0.2,               # Ambil 20% data dari setiap kelas
    stratify=filtered_data['genre'],      # Stratifikasi berdasarkan kolom 'genre'
    random_state=40
)
# Hasil stratified_sample berisi 20% sampel dari setiap genre
stratified_sample
# Out:
#                                               name     rating      genre  \
# 22                                    Annihilation          R  Adventure
# 78                                       Searching      PG-13      Drama
# 155                                 Captain Marvel      PG-13     Action
# 226                                    The Kitchen          R     Action
# 124                                      Hell Fest          R     Horror
# 26                                      Death Wish          R     Action
# 87                                   Hotel Artemis          R     Action
# 183                                    Toy Story 4          G  Animation
# 89                                       Book Club      PG-13     Comedy
# 247                                   Breakthrough         PG  Biography
# 100                                      Andhadhun  Not Rated      Crime
# 203            A Beautiful Day in the Neighborhood         PG  Biography
# ...

# %%
stratified_sample.head(30)
# Out:
#                                     name     rating      genre  year  \
# 22                          Annihilation          R  Adventure  2018
# 78                             Searching      PG-13      Drama  2018
# 155                       Captain Marvel      PG-13     Action  2019
# 226                          The Kitchen          R     Action  2019
# 124                            Hell Fest          R     Horror  2018
# 26                            Death Wish          R     Action  2018
# 87                         Hotel Artemis          R     Action  2018
# 183                          Toy Story 4          G  Animation  2019
# 89                             Book Club      PG-13     Comedy  2018
# 247                         Breakthrough         PG  Biography  2019
# 100                            Andhadhun  Not Rated      Crime  2018
# 203  A Beautiful Day in the Neighborhood         PG  Biography  2019
# 0                          A Quiet Place      PG-13      Drama  2018
# ...

# %%
stratified_sample.describe()
# Out:
#               year      score          votes        budget         gross  \
# count    55.000000  55.000000      55.000000  5.500000e+01  5.300000e+01
# mean   2018.545455   6.483636  122482.781818  5.234895e+07  2.122498e+08
# std       0.571489   0.963551  138902.961081  6.064599e+07  3.137791e+08
# min    2018.000000   3.100000      18.000000  5.000000e+03  5.040000e+04
# 25%    2018.000000   6.100000   28000.000000  1.000000e+07  3.162639e+07
# 50%    2019.000000   6.600000   73000.000000  3.000000e+07  9.149035e+07
# 75%    2019.000000   7.150000  147000.000000  7.750000e+07  2.140401e+08
# max    2020.000000   8.200000  603000.000000  2.750000e+08  1.131928e+09
#
#           runtime
# count   55.000000
# mean   108.763636
# std     17.746114
# min     77.000000
# 25%     96.500000
# 50%    104.000000
# 75%    119.000000
# max    161.000000

# %%
import scipy.stats as stats
import math

#specify sample mean (x_bar), sample standard deviation (s),
#sample size (n) and confidance level
x_bar = 5.23 #rata-rata
s = 6.06 #std sample
n = 5.50 #jumlah data (sample)
confidence_level = 0.90 #pilih antara 0.90 / 0.95 / 0.99

#calculate alpha, degrees of freedem (df), the critical t-value,
#and the margin of error
alpha = (1-confidence_level)
df = n - 1
standard_error = s/math.sqrt(n)
critical_t = stats.t.ppf(1-alpha/2, df)
margin_of_error = critical_t * standard_error

#calculate the lower and upper bound of the confidence interval
lower_bound = x_bar - margin_of_error
upper_bound = x_bar + margin_of_error

#print the results
print("Critical t-value: {:.2f}".format(critical_t))
print("Margin of error: {:.2f}".format(margin_of_error))
print("Confidence interval: ({:.2f}, {:.2f})".format(lower_bound, upper_bound))
print("The {:.1%} confidence interval for the population mean is:".format(confidence_level))
print("between {:.2f} and {:.2f}".format(lower_bound, upper_bound))
# Out:
# Critical t-value: 2.07
# Margin of error: 5.34
# Confidence interval: (-0.11, 10.57)
# The 90.0% confidence interval for the population mean is:
# between -0.11 and 10.57
